# %%
import time
import pandas as pd
from dict_combine import DictCombine

# %%
# dicts_combine = DictCombine.init(word="Spiel", dicts_to_use=["pons", "linguee"], pos="noun")

# %%
reactor_df = pd.read_excel("lln_excel_items_2022-10-6_8170477.xlsx")
cols_to_keep = ["Item type", "Subtitle", "Translation", "Word", "Lemma", "Word definition", "Part of speech"]
new_cols = ["item_type", "subtitle", "translation", "word", "lemma", "definition", "part_of_speech"]
col_map = {x: y for x, y in zip(cols_to_keep, new_cols)}
reactor_df = reactor_df[cols_to_keep]
reactor_df.rename(columns=col_map, inplace=True)

final_cols = ["German", "Picture", "English", "Audio", "Sample sentence", 
              "Plural and inflected forms", "German Alternatives", 
              "English Alternatives", "Part of speech", "original_word",
              "Source"]

# %%
reactor_df
# Out:
#     item_type                                           subtitle  \
# 0        Word  Meine Männer haben Gemetzel überstanden. So et...
# 1        Word  aus versehen das ist besonders tragisch weil n...
# 2        Word  Ich, Askeladd, Sohn von Olaf, nehme diesen Auf...
# 3        Word                       Ist das nicht Verschwendung?
# 4        Word                       Warum bist du so nachlässig?
# ..        ...                                                ...
# 437      Word                               Seid ihr bescheuert?
# 438    Phrase       und du gemerkt hast, wie erbärmlich du bist?
# 439      Word       und du gemerkt hast, wie erbärmlich du bist?
# 440    Phrase            ...war er ein kleiner verstörter Junge.
# 441      Word            ...war er ein kleiner verstörter Junge.
#
#                                            translation           word  \
# 0    My men have survived carnage. Something like t...       Gemetzel
# 1    this is particularly tragic because never just...       versehen
# 2    I, Askeladd, son of Olaf, humbly accept this a...        demütig
# 3                                  Isn't that a waste?  Verschwendung
# 4                             Why are you so careless?     nachlässig
# ..                                                 ...            ...
# 437                                    Are you stupid?     bescheuert
# 438             and you realized how pathetic you are?            NaN
# 439             and you realized how pathetic you are?     erbärmlich
# 440                ... he was a little distraught boy.            NaN
# 441                ... he was a little distraught boy.     verstörter
#
#              lemma                   definition part_of_speech
# 0         gemetzel                    slaughter           Noun
# 1         versehen  mistake, oversight, furnish            Adj
# 2          demütig       humbly, humble, meekly            Adj
# 3    verschwendung                        waste           Noun
# 4       nachlässig                  negligently            Adj
# ..             ...                          ...            ...
# 437     bescheuert                         daft           Verb
# 438            NaN                          NaN            NaN
# 439     erbärmlich                      pitiful            Adj
# 440            NaN                          NaN            NaN
# 441       verstört       distraught, distracted            Adj
#
# [442 rows x 7 columns]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
anki_csv = "ready_for_anki.csv"
while True:
    try:
        ready_for_anki = pd.read_csv("ready_for_anki3.csv", names=final_cols, header=None)
    except FileNotFoundError:
        ready_for_anki = pd.DataFrame()
    ready_entries = []
    for ix, row in reactor_df.loc[reactor_df.item_type == "Word"].iterrows():
        print(ix)
        print(row.word)
        
        if ix < 76:
            continue

        if not ready_for_anki.empty:
#             import pdb; pdb.set_trace()
            if row.lemma.lower() in ready_for_anki.original_word.to_list():
                continue
        example_src = row.subtitle if "..." not in row.subtitle else ""
        example_dst = row.translation if "..." not in  row.translation else ""
        ready_entry = DictCombine.init(word=row.lemma, 
                                       dicts_to_use=["pons", "linguee"], 
                                       pos=row.part_of_speech.lower(),
                                       external_example_dst=example_dst,
                                       external_example_src=example_src,
                                       source="Language Factory"
                                       )
    #     import pdb; pdb.set_trace()
        ready_entry = ready_entry()
        if not ready_entry:
            import pdb; pdb.set_trace()
            continue
        ready_entries.append(ready_entry)
        time.sleep(10)
        if ix % 10 == 1:
#             import pdb; pdb.set_trace()
            df_tmp = pd.DataFrame(ready_entries)
            ready_entries = []
            ready_for_anki = ready_for_anki.append(df_tmp)
            ready_for_anki.to_csv("ready_for_anki.csv3", index=False)
    df_tmp = pd.DataFrame(ready_entries)
    ready_for_anki = ready_for_anki.append(df_tmp)
    ready_for_anki.to_csv("ready_for_anki3.csv", index=False)
# Out:
# 0
# Gemetzel
# 1
# versehen
# 2
# demütig
# 3
# Verschwendung
# 4
# nachlässig
# 5
# Vorfahren
# 6
# eingebildet
# 7
# anständig
# 9
# Nebenbei
# 10
# entschlossen
# 11
# Jenseits
# 12
# verschwiegen
# 13
# Beförderung
# 14
# Not
# 15
# beleidigen
# 16
# Zwerg
# 17
# Seil
# 18
# Gedenkstein
# 19
# verehrt
# 20
# Geisel
# 21
# bestimmen
# 22
# vergeudet
# 23
# verstößt
# 24
# kotzen
# 25
# losgegangen
# 26
# aufgelöst
# 28
# Aufruhrs
# 29
# erlassen
# 30
# erlöst
# 31
# Puppe
# 32
# kleben
# 33
# angemessen
# 34
# genesen
# 35
# bereist
# 36
# nachvollziehen
# 37
# tapfer
# 38
# Verwirrung
# 39
# Schwachstelle
# 40
# Verletzlichkeit
# 41
# Strömung
# 42
# Scheiben
# 43
# verheilt
# 44
# vertraut
# 45
# Ertrinken
# 46
# vorzüglich
# 48
# Ärgerlich
# 49
# Quere
# 50
# Anwesen
# 51
# weigern
# 52
# Dagegen
# 53
# Unterschätz
# 54
# Pfeile
# 55
# festgelegt
# 56
# ausweiche
# 57
# Rücksicht
# 58
# wiegt
# 59
# dermaßen
# 60
# Erscheinung
# 61
# schwindlig
# 62
# Gerüchten
# 63
# ekelhafter
# 64
# Entführten
# 65
# Trauer
# 66
# Trost
# 67
# flach
# 68
# aufgespalten
# 69
# auslöschen
# 70
# Schimmer
# 71
# aussuchen
# 72
# Schädel
# 73
# abgewehrt
# 74
# bezwingen
# 75
# belegt
# 76
# einsam
# http://127.0.0.1:8000/api/v2/translations?query=einsam&src=en&dst=de&guess_direction=true&follow_corrections=always
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#      19     example_src = row.subtitle if "..." not in row.subtitle else ""
#      20     example_dst = row.translation if "..." not in  row.translation else ""
# ---> 21     ready_entry = DictCombine.init(word=row.lemma,
#      22                                    dicts_to_use=["pons", "linguee"],
#      23                                    pos=row.part_of_speech.lower(),
#      24                                    external_example_dst=example_dst,
#      25                                    external_example_src=example_src,
#      26                                    source="Language Factory"
#      27                                    )
#      28 #     import pdb; pdb.set_trace()
#      29     ready_entry = ready_entry()
#
# File ~/dict_to_anki/dict_combine.py:59, in DictCombine.init(cls, word, dicts_to_use, pos, input_lang, manual_selection, source, src_lang, dst_lang, external_example_src, external_example_dst, collections_path)
#      57         dicts.append(d)
#      58     elif dtu == "linguee":
# ---> 59         raise TooManyRequestsError("Linguee too many requests error.")
#      60 return cls(dicts=dicts,
#      61            dict_names=dicts_to_use,
#      62            external_example_src=external_example_src,
#      63            external_example_dst=external_example_dst)
#
# TooManyRequestsError: Linguee too many requests error.

# %%
# %debug

# %%
        ready_entry = DictCombine.init(word=row.lemma, 
                                       dicts_to_use=["pons", "linguee"], 
                                       pos=row.part_of_speech.lower())

# %%
# %debug

# %%
dicts_combine.entries

# %%
dicts_combine.anki_row

# %%
dicts_combine.dicts[0].entries

# %%
dicts_combine.dicts[1].entries
