# %%
from dict_combine import DictCombine

# %%
dicts_combine = DictCombine.init(word="Spiel", dicts_to_use=["pons", "linguee"], pos="noun")
# Out:
# /home/artursil/anaconda3/envs/ai/lib/python3.9/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# https://linguee-api.fly.dev/api/v2/translations?query=Spiel&src=en&dst=de&guess_direction=true&follow_corrections=always

# %%
dicts_combine.entries
# Out:
# {'pons': {'processed_word': 'das Spiel(nach regeln)',
#   'picture': "<img src='game.jpg'>",
#   'definition': 'game',
#   'audio': '',
#   'example_src': 'ein Spiel machen (spielen)<br>ein Spiel spielen',
#   'gender_src': 'neuter',
#   'gender_dst': '',
#   'tenses_plural': '<-[e]s, -e>',
#   'example_dst': 'to play a game<br>to play a game',
#   'pos': 'noun',
#   'pos_dst': '',
#   'original_word': 'das Spiel(nach regeln)',
#   'source': 'manual'},
#  'linguee': {'processed_word': 'das Spiel',
#   'picture': "<img src='game.jpg'>",
#   'definition': 'game',
#   'audio': '[sound:das Spiel.mp3]',
#   'example_src': 'Die Kinder spielten den ganzen Tag Spiele.<br>Ich habe das Spiel fast gewonnen.',
#   'gender_src': 'neuter',
#   'gender_dst': 'feminine',
#   'tenses_plural': None,
#   'example_dst': 'The children played games all day.<br>I nearly won the game.',
#   'pos': 'noun',
#   'pos_dst': 'noun',
#   'original_word': 'das Spiel',
#   'source': 'manual'}}

# %%
dicts_combine.anki_row
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 dicts_combine.anki_row
#
# File ~/dict_to_anki/dict_combine.py:133, in DictCombine.anki_row(self)
#     125 @property
#     126 def anki_row(self):
#     127     row_dict = {
#     128         "German": self.processed_word,
#     129         "Picture": self.picture,
#     130         "English": self.definition,
#     131         "Audio": self.audio,
#     132         "Sample sentence": self.example_src,
# --> 133         "Plural and inflected forms": self.tenses_plural,
#     134         "German Alternatives": "",
#     135         "English Alternatives": self.example_dst,
#     136         "Part of speech": self.pos,
#     137         "original_word": self.original_word,
#     138         "Source": self.source
#     139     }
#     140     return row_dict
#
# File ~/dict_to_anki/dict_combine.py:107, in DictCombine.tenses_plural(self)
#     105 @property
#     106 def tenses_plural(self):
# --> 107     return self.__return_single_value("tenses_plural")
#
# File ~/dict_to_anki/dict_combine.py:63, in DictCombine.__return_single_value(self, key, sort)
#      62 def __return_single_value(self, key: str, sort: list = []):
# ---> 63     df = self.__prepare_df(key, sort)
#      64     return df.iloc[0].value
#
# File ~/dict_to_anki/dict_combine.py:50, in DictCombine.__prepare_df(self, key, sort)
#      48 df = pd.DataFrame()
#      49 kk = [k for k in self.entries.keys()]
# ---> 50 vv = [v.get(key) for v in self.entries.values()]
#      51 df["dictionary"] = kk
#      52 df["value"] = vv
#
# File ~/dict_to_anki/dict_combine.py:44, in DictCombine.entries(self)
#      42 entries = {}
#      43 for d, n in zip(self.dicts, self.dict_names):
# ---> 44     entries[n] = d()
#      45 return entries
#
# File ~/dict_to_anki/dict_entry.py:201, in DictEntry.__call__(self)
#     200 def __call__(self):
# --> 201     return self.get_dict()
#
# File ~/dict_to_anki/dict_entry.py:185, in DictEntry.get_dict(self)
#     180 else:
#     181     processed_word = self.word
#     183 row_dict = {
#     184     "processed_word": processed_word,
# --> 185     "picture": self.image,
#     186     "definition": self.definition,
#     187     "audio": self.audio,
#     188     "example_src": self.example_src,
#     189     "gender_src": self.gender_src,
#     190     "gender_dst": self.gender_dst,
#     191     "tenses_plural": self.tenses_plural,
#     192     "example_dst": self.example_dst,
#     193     "pos": self.pos,
#     194     "pos_dst": self.pos_dst,
#     195     "original_word": self.word,
#     196     "source": self.source
#     197 }
#     198 return row_dict
#
# File ~/dict_to_anki/dict_entry.py:48, in DictEntry.image(self)
#      46 else:
#      47     img_word = self.word
# ---> 48 image_path = downloadimages(img_word)
#      49 img_name = image_path.parent.stem + image_path.suffix
#      50 img_dst = self.collections_path / img_name
#
# File ~/dict_to_anki/utils.py:18, in downloadimages(query)
#       8 def downloadimages(query):
#       9     # keywords is the search query
#      10     # format is the image file format
#    (...)
#      15     # aspect ratio denotes the height width ratio
#      16     # of images to download. ("tall, square, wide, panoramic")
#      17     query = query.split(",")[0]
# ---> 18     response().download(query, 10)
#      19     image = Path.cwd() / "simple_images" / query
#      20     files = list(image.glob("*"))
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/simple_image_download/simple_image_download.py:94, in simple_image_download.download(self, keywords, limit)
#      91 filename = str(keyword_to_search[i]) + "_" + str(j + 1) + ".jpg"
#      93 try:
# ---> 94     r = requests.get(object_raw, allow_redirects=True)
#      95     open(os.path.join(path, filename), 'wb').write(r.content)
#      96 except Exception as e:
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/ai/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/ai/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/anaconda3/envs/ai/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/anaconda3/envs/ai/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/ai/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/anaconda3/envs/ai/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/ai/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dicts_combine.dicts[0].entries

# %%
dicts_combine.dicts[1].entries
